# %%
import pandas as pd

# %%
df = pd.read_json(r"C:\Users\User\starwars_dataset.json")

# %%
df
# Out:
#                                               document_id  chunk_id  \
# 0       sharpkeeningat85cyclesfollowedbyfiveatonalmand...         1
# 1       sharpkeeningat85cyclesfollowedbyfiveatonalmand...         2
# 2                               thatjoyousnightiatemymate         1
# 3                        thatjoyousnightiatemymatelegends         1
# 4                                48-caliberenforcerpistol         1
# ...                                                   ...       ...
# 167203                                       gorntlegends         2
# 167204                                         gorntseron         1
# 167205                                         gorntseron         2
# 167206                                         gorntseron         3
# 167207                                  gorntseronscastle         1
#
#                                                     title  \
# 0       (Sharp keening at 85 cycles, followed by five ...
# ...
